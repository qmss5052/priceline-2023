# %% [markdown]
# TripAdvisor-Top 30 Attractions

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries
import requests
import pandas as pd
import csv
from bs4 import BeautifulSoup
from numpy import NAN

# %%
# Define a user agent to qualify request
user_agent = ({"User-Agent":
                    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                    AppleWebKit/537.36 (KHTML, like Gecko) \
                    Chrome/90.0.4430.212 Safari/537.36",
               "Accept-Language": "en-US, en;q=0.5"})

# %%
# Import the list of main pages
df = pd.read_csv("/content/drive/MyDrive/Priceline/JintongYu/TA_about_links.csv")
main_pages = df["TA_main_page"].tolist()

# %%
# Define a function to extract the characters of the attractions on the 1st page for each city
def todo_30(main_page):
  try:
    # Send an HTTP GET request to the main link and retrieve the HTML content
    response = requests.get(main_page, headers=user_agent)
    html_content = response.content

    # Parse the HTML content to extract the subdirectory link
    soup = BeautifulSoup(html_content, "html.parser")
    subdirectory_link = soup.find("a", href=lambda href: href and "/Attractions-" in href).get("href")

    # Construct the full subdirectory link
    full_subdirectory_link = "https://www.tripadvisor.com" + subdirectory_link

    # Send an HTTP GET request to the subdirectory link and retrieve the HTML content
    response = requests.get(full_subdirectory_link, headers=user_agent)
    html_content = response.content

    # Send an HTTP GET request to the sub-subdirectory link and retrieve the HTML content
    soup = BeautifulSoup(html_content, "html.parser")
    sub_subdirectory_link = soup.find("a", href=lambda href: href and "/Attractions-" and "oa0" in href).get("href")
    full_sub_subdirectory_link = "https://www.tripadvisor.com" + sub_subdirectory_link
    response = requests.get(full_sub_subdirectory_link, headers=user_agent)
    html_content = response.content

    # Parse the HTML content of the sub-subdirectory link
    soup = BeautifulSoup(html_content, "html.parser")
    # Extract characters of the 1st page attractions (30) as a whole
    characters = []
    for tag in soup.find_all('div', {'class': 'alPVI eNNhq PgLKC tnGGX yzLvM'}):
      if tag.find('div', {'class': 'biGQs _P pZUbB hmDzD'}, recursive=False) is not None:
        character_tags = tag.find('div', {'class': 'biGQs _P pZUbB hmDzD'}, recursive=False)
    
        for tag in character_tags:
          content = tag.get_text()
          characters.append(content)

    return{
        "attractions_url": full_sub_subdirectory_link,
        "30_attractions_char": characters
    }
  except:
    return{
        "attractions_url": NAN,
        "30_attractions_char": NAN
        }

# %%
# # Trial 1
# main_page = "https://www.tripadvisor.com/Tourism-g60763-New_York_City_New_York-Vacations.html"
# todo_30(main_page)

# %%
# # Trial 2
# url = 'https://www.tripadvisor.com/Attractions-g60763-Activities-oa0-New_York_City_New_York.html'
# response = requests.get(url, headers=user_agent)
# html_content = response.content

# # Parse the HTML content
# soup = BeautifulSoup(html_content, 'html.parser')

# # Find the container div for the attraction listings

# # Find all the div tags with class 'biGQs _P pZUbB hmDzD' that are immediate children of a div with class 'alPVI eNNhq PgLKC tnGGX yzLvM'
# characters = []
# for tag in soup.find_all('div', {'class': 'alPVI eNNhq PgLKC tnGGX yzLvM'}):
#   if tag.find('div', {'class': 'biGQs _P pZUbB hmDzD'}, recursive=False) is not None:
#     character_tags = tag.find('div', {'class': 'biGQs _P pZUbB hmDzD'}, recursive=False)
    
#     for tag in character_tags:
#       content = tag.get_text()
#       characters.append(content)

# # character_tags
# characters

# %%
# Extract "todo_30" for all cities
results = []
for main_page in main_pages:
  results.append(todo_30(main_page))

# %%
# Turn dictionary into a dataframe
todo_30_df = pd.DataFrame.from_dict(results)
todo_30_df.head()
# Out:
#                                      attractions_url  \
# 0  https://www.tripadvisor.com/Attractions-g18779...
# 1  https://www.tripadvisor.com/Attractions-g18749...
# 2  https://www.tripadvisor.com/Attractions-g29397...
# 3  https://www.tripadvisor.com/Attractions-g18784...
# 4  https://www.tripadvisor.com/Attractions-g18789...
#
#                                  30_attractions_char
# 0  [Historic Sites • Ancient Ruins, Ancient Ruins...
# 1  [Points of Interest & Landmarks • Architectura...
# 2  [Historic Sites • Architectural Buildings, His...
# 3  [Religious Sites • Churches & Cathedrals, Poin...
# 4  [Points of Interest & Landmarks, Art Museums, ...

# %%
# Concate the "todo_30" dataframe with the original city list
todo_30_df_concat = pd.concat([df.iloc[:, 0:5], todo_30_df], axis=1)
todo_30_df_concat.head()
# Out:
#        region_name country_code      province_name  city_name  \
# 0  SOUTHERN EUROPE           IT              LAZIO       ROME
# 1  SOUTHERN EUROPE           SP          CATALONIA  BARCELONA
# 2  SOUTHERN EUROPE           TU           ISTANBUL   ISTANBUL
# 3  SOUTHERN EUROPE           IT          LOMBARDIA      MILAN
# 4  SOUTHERN EUROPE           IT  TOSCANA (TUSCANY)   FLORENCE
#
#    region_city_rank                                    attractions_url  \
# 0                 1  https://www.tripadvisor.com/Attractions-g18779...
# 1                 2  https://www.tripadvisor.com/Attractions-g18749...
# 2                 3  https://www.tripadvisor.com/Attractions-g29397...
# 3                 4  https://www.tripadvisor.com/Attractions-g18784...
# 4                 5  https://www.tripadvisor.com/Attractions-g18789...
#
#                                  30_attractions_char
# 0  [Historic Sites • Ancient Ruins, Ancient Ruins...
# 1  [Points of Interest & Landmarks • Architectura...
# 2  [Historic Sites • Architectural Buildings, His...
# 3  [Religious Sites • Churches & Cathedrals, Poin...
# 4  [Points of Interest & Landmarks, Art Museums, ...

# %%
# Check whether there are cities with empty target content
todo_30_df.describe(include='all')
# Out:
#                                           attractions_url  \
# count                                                 178
# unique                                                178
# top     https://www.tripadvisor.com/Attractions-g18779...
# freq                                                    1
#
#                                       30_attractions_char
# count                                                 178
# unique                                                178
# top     [Historic Sites • Ancient Ruins, Ancient Ruins...
# freq                                                    1

# %%
# List the cities w/o the target content
todo_30_df[todo_30_df['attractions_url'].isnull()]
# Out:
#     attractions_url 30_attractions_char
# 52              NaN                 NaN
# 101             NaN                 NaN

# %%
# Save to a CSV file
todo_30_df_concat.to_csv("todo_30.csv")
